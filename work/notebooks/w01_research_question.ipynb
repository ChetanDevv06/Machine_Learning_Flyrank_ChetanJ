# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
CTR / Engagement Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
The model helps determine which web pages should be prioritized for CTR optimization. Instead of reviewing every page, it ranks pages with the greatest opportunity for improvement.
    
The recommendations are used by SEO specialists, content marketers, or website managers, who decide which pages to update by improving titles, meta descriptions, or other elements that influence click-through rates.

A wrong recommendation can cause the team to spend time and resources optimizing pages with little improvement potential while overlooking pages that could have generated significant increases in traffic. This leads to inefficient use of resources and missed opportunities for higher organic search performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import numpy as np

# Load the data
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# Calculate key statistics for CTR/Engagement Opportunity Scoring
avg_ctr = df['ctr'].mean()
median_engagement = df['engagement_rate'].median()
high_traffic_low_ctr = df[(df['impressions_90d'] > 5000) & (df['ctr'] < 0.5)].shape[0]

print(f"Average CTR across all content: {avg_ctr:.2f}%")
print(f"Median engagement rate: {median_engagement:.2f}%")
print(f"Pages with high traffic (>5K impressions) but low CTR (<0.5%): {high_traffic_low_ctr}")
print(f"These pages represent major opportunities for optimization that could significantly improve overall performance.")
# Out:
# Average CTR across all content: 0.51%
# Median engagement rate: 0.00%
# Pages with high traffic (>5K impressions) but low CTR (<0.5%): 4958
# These pages represent major opportunities for optimization that could significantly improve overall performance.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
### What my work can claim
- Identify pages with high CTR improvement potential.
- Rank pages based on opportunity.
- Support SEO decision-making.

### What my work cannot claim
- Prove causation.
- Predict Google's ranking algorithm.
- Guarantee higher rankings or traffic.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✓] Every section above is filled — markdown thinking AND the code that backs it
# - [✓] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✓] No client names, URLs, or private queries anywhere
# - [✓] My claims use careful words: observed, measured, directional, decision-support
# - [✓] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
